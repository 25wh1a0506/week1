# %%
fruits=["apple","banana","orange"]
print("the fruits are:",fruits)
print("first fruit:",fruits[0])
# Out:
# the fruits are: ['apple', 'banana', 'orange']
# first fruit: apple

# %%
fruits.append("lychee")
print("after addition:",fruits)
# Out:
# after addition: ['apple', 'banana', 'orange', 'lychee']

# %%
fruits.remove("apple")
print("after removal:",fruits)
# Out:
# after removal: ['banana', 'orange', 'lychee']

# %%
print("length of the fruits:",len(fruits))
# Out:
# length of the fruits: 3

# %%
dimensions=(9,12,16)
print("elements in dimensions are:",dimensions)
# Out:
# elements in dimensions are: (9, 12, 16)

# %%
print("second element is:",dimensions[1])
# Out:
# second element is: 12

# %%
set1={2,4,6,8,10}
print("elements in set:",set1)
# Out:
# elements in set: {2, 4, 6, 8, 10}

# %%
set1.add(1)
print("after addition:",set1)
# Out:
# after addition: {1, 2, 4, 6, 8, 10}

# %%
set1.remove(10)
print("after removing:",set1)
# Out:
# after removing: {1, 2, 4, 6, 8}

# %%
seta={1,2,3,4}
setb={5,6,4,7,8}
print("union:",seta|setb)
print("inersection:",seta&setb)
print("difference",seta-setb)
# Out:
# union: {1, 2, 3, 4, 5, 6, 7, 8}
# inersection: {4}
# difference {1, 2, 3}

# %%
student={
    'name':'sonu',
    'age':'18',
    'course':'cse'
}
print("dictonary:",student)
# Out:
# dictonary: {'name': 'sonu', 'age': '18', 'course': 'cse'}

# %%
print("name:",student['name'])
# Out:
# name: sonu

# %%
student['grade']='A'
print(student)
# Out:
# {'name': 'sonu', 'age': '18', 'course': 'cse', 'grade': 'A'}

# %%
del student['age']
print("After deleting age:", student)
# Out:
# After deleting age: {'name': 'sonu', 'course': 'cse', 'grade': 'A'}

# %%
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# name: sonu
# course: cse
# grade: A

# %%
keys = ['rollno.', 'name', 'marks']
values = [506, 'honey', 88]
student_info = dict(zip(keys, values))
print("student info from zip:", student_info)
# Out:
# student info from zip: {'rollno.': 506, 'name': 'honey', 'marks': 88}
