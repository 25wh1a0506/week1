# %%
def greet():
    print("Hello! Welcome to Python Functions.")
greet()

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Maxie")
greet_user("Bannu")

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()
greet_user("eva")

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Maxie", "Bannu", "Charlie")

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Maxie", age=18, city="Hyd")

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="eva", city="Mumbai")


def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 7:", square(7))
# Out:
# Hello! Welcome to Python Functions.
# Hello, Maxie!
# Hello, Bannu!
# Welcome, Guest!
# Welcome, eva!
# Names passed: ('Maxie', 'Bannu', 'Charlie')
# Hello Maxie
# Hello Bannu
# Hello Charlie
# User Info:
# name = Maxie
# age = 18
# city = Hyd
# Args: (1, 2, 3)
# Kwargs: {'name': 'eva', 'city': 'Mumbai'}
# Square of 7: 49
